# %% [markdown]
# This notebook is just the same code as the one in Create_GAF_images.ipynb, but only keeping the final implementation. Besides, the npy files are not stored in OneDrive, but in a different folder.

# %%
# Para trabajar con ficheros en Google Drive desde Google Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.listdir('/content/drive/MyDrive/Colab Notebooks/deep_acelerometry')
# Out:
# ['target.csv',
#  'matrix_3d.npy',
#  'matrix_SEQN.csv',
#  'test_IDs.csv',
#  'train_IDs.csv',
#  'X_test.csv',
#  'y_train.csv',
#  'X_train.csv',
#  'y_test.csv',
#  'Create_tensors.ipynb',
#  'Otros notebooks',
#  'Regression with CNNs.ipynb',
#  'Classification with CNNs.ipynb',
#  'tensors_144',
#  'Copia de Create_tensors.ipynb']

# %%
#Cambiar directorio de trabajo
# %cd '/content/drive/MyDrive/Colab Notebooks/deep_acelerometry'
# Out:
# /content/drive/MyDrive/Colab Notebooks/deep_acelerometry

# %%
pip install pyts
# Out:
# Collecting pyts
#   Downloading pyts-0.13.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.12/dist-packages (from pyts) (2.0.2)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from pyts) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from pyts) (1.6.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from pyts) (1.5.3)
# Requirement already satisfied: numba>=0.55.2 in /usr/local/lib/python3.12/dist-packages (from pyts) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.55.2->pyts) (0.43.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2.0->pyts) (3.6.0)
# Downloading pyts-0.13.0-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 38.7 MB/s eta 0:00:00
# Installing collected packages: pyts
# Successfully installed pyts-0.13.0

# %%
import numpy as np
import pandas as pd
import os

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from pyts.image import GramianAngularField

# %% [markdown]
# ## 1 Import accelerometry data and subjects' sequence number (ID)

# %% [markdown]
# First, we load the following data:
# - **matrix_3d.npy**: 3D matrix of accelerometry data. See 6_generate_time_series_matrix.ipynb for details.
# - **matrix_SEQN.csv**: Sequence number (SEQN) of subjects in the same order as the rows of the 3D matrix. See 6_generate_time_series_matrix.ipynb for details.
# - **train_ids.csv**: Sequence number of subjects in the training set.
# - **test_ids.csv**: Sequence number of subjects in the test set.

# %%
physical_activity = np.load('matrix_3d.npy')
subjects_seqn = pd.read_csv('matrix_SEQN.csv')
train_ids = pd.read_csv('train_IDs.csv', names=['SEQN'])
test_ids = pd.read_csv('test_IDs.csv', names=['SEQN'])

# %%
physical_activity.shape # nof_subjects, 7 days, 1440 minutes
# Out:
# (7537, 7, 1440)

# %%
nof_subjects = physical_activity.shape[0] # 7537 subjects
nof_days = physical_activity.shape[1] # 7 days
nof_minutes_per_day = physical_activity.shape[2] # 1440 minutes

# %%
subjects_seqn.shape # nof_subjects
# Out:
# (7537, 1)

# %% [markdown]
# We have therefore the SEQN values that identify each subject. To identify the subject in the 3D matrix, we need to map those SEQN values to the row index of the 3D matrix. To do so, the following dictionary is created:

# %%
seqn_to_index = {seqn: idx for idx, seqn in enumerate(subjects_seqn['SEQN'].values)} # A dictionary to map SEQN to index

# %% [markdown]
# Testing dictionary

# %%
seqn_to_index
# Out:
# {np.float64(73557.0): 0,
#  np.float64(73558.0): 1,
#  np.float64(73559.0): 2,
#  np.float64(73560.0): 3,
#  np.float64(73561.0): 4,
#  np.float64(73562.0): 5,
#  np.float64(73564.0): 6,
#  np.float64(73566.0): 7,
#  np.float64(73567.0): 8,
#  np.float64(73568.0): 9,
#  np.float64(73570.0): 10,
#  np.float64(73571.0): 11,
#  np.float64(73572.0): 12,
#  np.float64(73573.0): 13,
#  np.float64(73574.0): 14,
#  np.float64(73576.0): 15,
#  np.float64(73579.0): 16,
#  np.float64(73580.0): 17,
#  np.float64(73581.0): 18,
#  np.float64(73583.0): 19,
#  np.float64(73585.0): 20,
#  np.float64(73586.0): 21,
#  np.float64(73587.0): 22,
#  np.float64(73588.0): 23,
#  np.float64(73589.0): 24,
#  np.float64(73591.0): 25,
#  np.float64(73592.0): 26,
#  np.float64(73594.0): 27,
#  np.float64(73595.0): 28,
#  np.float64(73596.0): 29,
#  np.float64(73597.0): 30,
#  np.float64(73598.0): 31,
#  np.float64(73599.0): 32,
#  np.float64(73600.0): 33,
#  np.float64(73602.0): 34,
#  np.float64(73603.0): 35,
#  np.float64(73604.0): 36,
#  np.float64(73605.0): 37,
#  np.float64(73606.0): 38,
#  np.float64(73607.0): 39,
#  np.float64(73608.0): 40,
#  np.float64(73609.0): 41,
#  np.float64(73610.0): 42,
#  np.float64(73612.0): 43,
#  np.float64(73613.0): 44,
#  np.float64(73614.0): 45,
#  np.float64(73615.0): 46,
#  np.float64(73616.0): 47,
#  np.float64(73617.0): 48,
#  np.float64(73618.0): 49,
#  np.float64(73619.0): 50,
#  np.float64(73620.0): 51,
#  np.float64(73621.0): 52,
#  np.float64(73622.0): 53,
#  np.float64(73623.0): 54,
#  np.float64(73624.0): 55,
#  np.float64(73626.0): 56,
#  np.float64(73628.0): 57,
#  np.float64(73629.0): 58,
#  np.float64(73630.0): 59,
#  np.float64(73631.0): 60,
#  np.float64(73632.0): 61,
#  np.float64(73633.0): 62,
#  np.float64(73635.0): 63,
#  np.float64(73638.0): 64,
#  np.float64(73639.0): 65,
#  np.float64(73640.0): 66,
#  np.float64(73642.0): 67,
#  np.float64(73643.0): 68,
#  np.float64(73644.0): 69,
#  np.float64(73645.0): 70,
#  np.float64(73646.0): 71,
#  np.float64(73647.0): 72,
#  np.float64(73648.0): 73,
#  np.float64(73650.0): 74,
#  np.float64(73651.0): 75,
#  np.float64(73652.0): 76,
#  np.float64(73653.0): 77,
#  np.float64(73655.0): 78,
#  np.float64(73656.0): 79,
#  np.float64(73658.0): 80,
#  np.float64(73659.0): 81,
#  np.float64(73660.0): 82,
#  np.float64(73661.0): 83,
#  np.float64(73662.0): 84,
#  np.float64(73663.0): 85,
#  np.float64(73664.0): 86,
#  np.float64(73665.0): 87,
#  np.float64(73666.0): 88,
#  np.float64(73667.0): 89,
#  np.float64(73668.0): 90,
#  np.float64(73669.0): 91,
#  np.float64(73670.0): 92,
#  np.float64(73672.0): 93,
#  np.float64(73673.0): 94,
#  np.float64(73674.0): 95,
#  np.float64(73675.0): 96,
#  np.float64(73676.0): 97,
#  np.float64(73677.0): 98,
#  np.float64(73678.0): 99,
#  np.float64(73680.0): 100,
#  np.float64(73681.0): 101,
#  np.float64(73682.0): 102,
#  np.float64(73686.0): 103,
#  np.float64(73687.0): 104,
#  np.float64(73688.0): 105,
#  np.float64(73690.0): 106,
#  np.float64(73691.0): 107,
#  np.float64(73692.0): 108,
#  np.float64(73693.0): 109,
#  np.float64(73694.0): 110,
#  np.float64(73696.0): 111,
#  np.float64(73697.0): 112,
#  np.float64(73698.0): 113,
#  np.float64(73701.0): 114,
#  np.float64(73702.0): 115,
#  np.float64(73703.0): 116,
#  np.float64(73704.0): 117,
#  np.float64(73705.0): 118,
#  np.float64(73706.0): 119,
#  np.float64(73707.0): 120,
#  np.float64(73711.0): 121,
#  np.float64(73712.0): 122,
#  np.float64(73713.0): 123,
#  np.float64(73714.0): 124,
#  np.float64(73715.0): 125,
#  np.float64(73716.0): 126,
#  np.float64(73717.0): 127,
#  np.float64(73718.0): 128,
#  np.float64(73719.0): 129,
#  np.float64(73722.0): 130,
#  np.float64(73723.0): 131,
#  np.float64(73724.0): 132,
#  np.float64(73725.0): 133,
#  np.float64(73726.0): 134,
#  np.float64(73728.0): 135,
#  np.float64(73729.0): 136,
#  np.float64(73730.0): 137,
#  np.float64(73731.0): 138,
#  np.float64(73732.0): 139,
#  np.float64(73734.0): 140,
#  np.float64(73736.0): 141,
#  np.float64(73739.0): 142,
#  np.float64(73740.0): 143,
#  np.float64(73741.0): 144,
#  np.float64(73742.0): 145,
#  np.float64(73745.0): 146,
#  np.float64(73746.0): 147,
#  np.float64(73747.0): 148,
#  np.float64(73749.0): 149,
#  np.float64(73751.0): 150,
#  np.float64(73752.0): 151,
#  np.float64(73753.0): 152,
#  np.float64(73754.0): 153,
#  np.float64(73755.0): 154,
#  np.float64(73756.0): 155,
#  np.float64(73757.0): 156,
#  np.float64(73758.0): 157,
#  np.float64(73759.0): 158,
#  np.float64(73760.0): 159,
#  np.float64(73761.0): 160,
#  np.float64(73762.0): 161,
#  np.float64(73763.0): 162,
#  np.float64(73764.0): 163,
#  np.float64(73765.0): 164,
#  np.float64(73766.0): 165,
#  np.float64(73767.0): 166,
#  np.float64(73768.0): 167,
#  np.float64(73770.0): 168,
#  np.float64(73772.0): 169,
#  np.float64(73773.0): 170,
#  np.float64(73774.0): 171,
#  np.float64(73775.0): 172,
#  np.float64(73776.0): 173,
#  np.float64(73778.0): 174,
#  np.float64(73779.0): 175,
#  np.float64(73780.0): 176,
#  np.float64(73781.0): 177,
#  np.float64(73782.0): 178,
#  np.float64(73783.0): 179,
#  np.float64(73786.0): 180,
#  np.float64(73787.0): 181,
#  np.float64(73788.0): 182,
#  np.float64(73790.0): 183,
#  np.float64(73792.0): 184,
#  np.float64(73793.0): 185,
#  np.float64(73794.0): 186,
#  np.float64(73795.0): 187,
#  np.float64(73796.0): 188,
#  np.float64(73797.0): 189,
#  np.float64(73798.0): 190,
#  np.float64(73799.0): 191,
#  np.float64(73800.0): 192,
#  np.float64(73801.0): 193,
#  np.float64(73802.0): 194,
#  np.float64(73804.0): 195,
#  np.float64(73805.0): 196,
#  np.float64(73806.0): 197,
#  np.float64(73807.0): 198,
#  np.float64(73808.0): 199,
#  np.float64(73809.0): 200,
#  np.float64(73811.0): 201,
#  np.float64(73813.0): 202,
#  np.float64(73815.0): 203,
#  np.float64(73816.0): 204,
#  np.float64(73818.0): 205,
#  np.float64(73819.0): 206,
#  np.float64(73820.0): 207,
#  np.float64(73821.0): 208,
#  np.float64(73822.0): 209,
#  np.float64(73823.0): 210,
#  np.float64(73824.0): 211,
#  np.float64(73825.0): 212,
#  np.float64(73826.0): 213,
#  np.float64(73827.0): 214,
#  np.float64(73829.0): 215,
#  np.float64(73831.0): 216,
#  np.float64(73833.0): 217,
#  np.float64(73834.0): 218,
#  np.float64(73835.0): 219,
#  np.float64(73836.0): 220,
#  np.float64(73837.0): 221,
#  np.float64(73839.0): 222,
#  np.float64(73840.0): 223,
#  np.float64(73841.0): 224,
#  np.float64(73842.0): 225,
#  np.float64(73843.0): 226,
#  np.float64(73844.0): 227,
#  np.float64(73846.0): 228,
#  np.float64(73847.0): 229,
#  np.float64(73848.0): 230,
#  np.float64(73849.0): 231,
#  np.float64(73850.0): 232,
#  np.float64(73851.0): 233,
#  np.float64(73853.0): 234,
#  np.float64(73855.0): 235,
#  np.float64(73858.0): 236,
#  np.float64(73860.0): 237,
#  np.float64(73862.0): 238,
#  np.float64(73863.0): 239,
#  np.float64(73864.0): 240,
#  np.float64(73865.0): 241,
#  np.float64(73866.0): 242,
#  np.float64(73868.0): 243,
#  np.float64(73872.0): 244,
#  np.float64(73873.0): 245,
#  np.float64(73875.0): 246,
#  np.float64(73878.0): 247,
#  np.float64(73879.0): 248,
#  np.float64(73880.0): 249,
#  np.float64(73881.0): 250,
#  np.float64(73882.0): 251,
#  np.float64(73883.0): 252,
#  np.float64(73884.0): 253,
#  np.float64(73885.0): 254,
#  np.float64(73886.0): 255,
#  np.float64(73887.0): 256,
#  np.float64(73888.0): 257,
#  np.float64(73889.0): 258,
#  np.float64(73890.0): 259,
#  np.float64(73891.0): 260,
#  np.float64(73892.0): 261,
#  np.float64(73893.0): 262,
#  np.float64(73895.0): 263,
#  np.float64(73897.0): 264,
#  np.float64(73898.0): 265,
#  np.float64(73899.0): 266,
#  np.float64(73900.0): 267,
#  np.float64(73903.0): 268,
#  np.float64(73904.0): 269,
#  np.float64(73905.0): 270,
#  np.float64(73906.0): 271,
#  np.float64(73908.0): 272,
#  np.float64(73910.0): 273,
#  np.float64(73911.0): 274,
#  np.float64(73913.0): 275,
#  np.float64(73915.0): 276,
#  np.float64(73916.0): 277,
#  np.float64(73917.0): 278,
#  np.float64(73918.0): 279,
#  np.float64(73919.0): 280,
#  np.float64(73920.0): 281,
#  np.float64(73921.0): 282,
#  np.float64(73922.0): 283,
#  np.float64(73923.0): 284,
#  np.float64(73925.0): 285,
#  np.float64(73926.0): 286,
#  np.float64(73927.0): 287,
#  np.float64(73928.0): 288,
#  np.float64(73929.0): 289,
#  np.float64(73930.0): 290,
#  np.float64(73931.0): 291,
#  np.float64(73932.0): 292,
#  np.float64(73933.0): 293,
#  np.float64(73934.0): 294,
#  np.float64(73935.0): 295,
#  np.float64(73936.0): 296,
#  np.float64(73937.0): 297,
#  np.float64(73938.0): 298,
#  np.float64(73939.0): 299,
#  np.float64(73940.0): 300,
#  np.float64(73942.0): 301,
#  np.float64(73943.0): 302,
#  np.float64(73945.0): 303,
#  np.float64(73948.0): 304,
#  np.float64(73949.0): 305,
#  np.float64(73950.0): 306,
#  np.float64(73951.0): 307,
#  np.float64(73952.0): 308,
#  np.float64(73953.0): 309,
#  np.float64(73954.0): 310,
#  np.float64(73955.0): 311,
#  np.float64(73956.0): 312,
#  np.float64(73958.0): 313,
#  np.float64(73959.0): 314,
#  np.float64(73960.0): 315,
#  np.float64(73961.0): 316,
#  np.float64(73962.0): 317,
#  np.float64(73963.0): 318,
#  np.float64(73964.0): 319,
#  np.float64(73966.0): 320,
#  np.float64(73967.0): 321,
#  np.float64(73968.0): 322,
#  np.float64(73970.0): 323,
#  np.float64(73971.0): 324,
#  np.float64(73973.0): 325,
#  np.float64(73974.0): 326,
#  np.float64(73975.0): 327,
#  np.float64(73976.0): 328,
#  np.float64(73977.0): 329,
#  np.float64(73978.0): 330,
#  np.float64(73979.0): 331,
#  np.float64(73981.0): 332,
#  np.float64(73982.0): 333,
#  np.float64(73983.0): 334,
#  np.float64(73985.0): 335,
#  np.float64(73986.0): 336,
#  np.float64(73987.0): 337,
#  np.float64(73988.0): 338,
#  np.float64(73990.0): 339,
#  np.float64(73992.0): 340,
#  np.float64(73993.0): 341,
#  np.float64(73994.0): 342,
#  np.float64(73995.0): 343,
#  np.float64(73996.0): 344,
#  np.float64(73997.0): 345,
#  np.float64(73998.0): 346,
#  np.float64(73999.0): 347,
#  np.float64(74000.0): 348,
#  np.float64(74001.0): 349,
#  np.float64(74002.0): 350,
#  np.float64(74003.0): 351,
#  np.float64(74004.0): 352,
#  np.float64(74005.0): 353,
#  np.float64(74006.0): 354,
#  np.float64(74007.0): 355,
#  np.float64(74008.0): 356,
#  np.float64(74009.0): 357,
#  np.float64(74010.0): 358,
#  np.float64(74012.0): 359,
#  np.float64(74013.0): 360,
#  np.float64(74014.0): 361,
#  np.float64(74016.0): 362,
#  np.float64(74017.0): 363,
#  np.float64(74018.0): 364,
#  np.float64(74021.0): 365,
#  np.float64(74023.0): 366,
#  np.float64(74025.0): 367,
#  np.float64(74026.0): 368,
#  np.float64(74027.0): 369,
#  np.float64(74029.0): 370,
#  np.float64(74032.0): 371,
#  np.float64(74033.0): 372,
#  np.float64(74037.0): 373,
#  np.float64(74038.0): 374,
#  np.float64(74039.0): 375,
#  np.float64(74041.0): 376,
#  np.float64(74042.0): 377,
#  np.float64(74043.0): 378,
#  np.float64(74044.0): 379,
#  np.float64(74045.0): 380,
#  np.float64(74047.0): 381,
#  np.float64(74048.0): 382,
#  np.float64(74049.0): 383,
#  np.float64(74050.0): 384,
#  np.float64(74051.0): 385,
#  np.float64(74053.0): 386,
#  np.float64(74054.0): 387,
#  np.float64(74055.0): 388,
#  np.float64(74056.0): 389,
#  np.float64(74057.0): 390,
#  np.float64(74058.0): 391,
#  np.float64(74059.0): 392,
#  np.float64(74060.0): 393,
#  np.float64(74061.0): 394,
#  np.float64(74062.0): 395,
#  np.float64(74066.0): 396,
#  np.float64(74070.0): 397,
#  np.float64(74071.0): 398,
#  np.float64(74072.0): 399,
#  np.float64(74074.0): 400,
#  np.float64(74075.0): 401,
#  np.float64(74077.0): 402,
#  np.float64(74078.0): 403,
#  np.float64(74080.0): 404,
#  np.float64(74081.0): 405,
#  np.float64(74083.0): 406,
#  np.float64(74085.0): 407,
#  np.float64(74086.0): 408,
#  np.float64(74087.0): 409,
#  np.float64(74088.0): 410,
#  np.float64(74091.0): 411,
#  np.float64(74092.0): 412,
#  np.float64(74093.0): 413,
#  np.float64(74094.0): 414,
#  np.float64(74095.0): 415,
#  np.float64(74096.0): 416,
#  np.float64(74097.0): 417,
#  np.float64(74099.0): 418,
#  np.float64(74100.0): 419,
#  np.float64(74102.0): 420,
#  np.float64(74103.0): 421,
#  np.float64(74104.0): 422,
#  np.float64(74106.0): 423,
#  np.float64(74107.0): 424,
#  np.float64(74109.0): 425,
#  np.float64(74110.0): 426,
#  np.float64(74111.0): 427,
#  np.float64(74112.0): 428,
#  np.float64(74113.0): 429,
#  np.float64(74114.0): 430,
#  np.float64(74115.0): 431,
#  np.float64(74117.0): 432,
#  np.float64(74118.0): 433,
#  np.float64(74119.0): 434,
#  np.float64(74120.0): 435,
#  np.float64(74124.0): 436,
#  np.float64(74125.0): 437,
#  np.float64(74126.0): 438,
#  np.float64(74127.0): 439,
#  np.float64(74128.0): 440,
#  np.float64(74130.0): 441,
#  np.float64(74131.0): 442,
#  np.float64(74132.0): 443,
#  np.float64(74133.0): 444,
#  np.float64(74134.0): 445,
#  np.float64(74135.0): 446,
#  np.float64(74136.0): 447,
#  np.float64(74137.0): 448,
#  np.float64(74138.0): 449,
#  np.float64(74139.0): 450,
#  np.float64(74140.0): 451,
#  np.float64(74142.0): 452,
#  np.float64(74143.0): 453,
#  np.float64(74144.0): 454,
#  np.float64(74147.0): 455,
#  np.float64(74148.0): 456,
#  np.float64(74149.0): 457,
#  np.float64(74150.0): 458,
#  np.float64(74154.0): 459,
#  np.float64(74159.0): 460,
#  np.float64(74160.0): 461,
#  np.float64(74163.0): 462,
#  np.float64(74164.0): 463,
#  np.float64(74165.0): 464,
#  np.float64(74166.0): 465,
#  np.float64(74168.0): 466,
#  np.float64(74169.0): 467,
#  np.float64(74172.0): 468,
#  np.float64(74173.0): 469,
#  np.float64(74174.0): 470,
#  np.float64(74176.0): 471,
#  np.float64(74177.0): 472,
#  np.float64(74178.0): 473,
#  np.float64(74179.0): 474,
#  np.float64(74180.0): 475,
#  np.float64(74181.0): 476,
#  np.float64(74182.0): 477,
#  np.float64(74183.0): 478,
#  np.float64(74184.0): 479,
#  np.float64(74185.0): 480,
#  np.float64(74186.0): 481,
#  np.float64(74187.0): 482,
#  np.float64(74188.0): 483,
#  np.float64(74191.0): 484,
#  np.float64(74195.0): 485,
#  np.float64(74196.0): 486,
#  np.float64(74198.0): 487,
#  np.float64(74199.0): 488,
#  np.float64(74200.0): 489,
#  np.float64(74203.0): 490,
#  np.float64(74205.0): 491,
#  np.float64(74206.0): 492,
#  np.float64(74207.0): 493,
#  np.float64(74209.0): 494,
#  np.float64(74211.0): 495,
#  np.float64(74212.0): 496,
#  np.float64(74213.0): 497,
#  np.float64(74214.0): 498,
#  np.float64(74215.0): 499,
#  np.float64(74217.0): 500,
#  np.float64(74218.0): 501,
#  np.float64(74220.0): 502,
#  np.float64(74221.0): 503,
#  np.float64(74222.0): 504,
#  np.float64(74224.0): 505,
#  np.float64(74225.0): 506,
#  np.float64(74227.0): 507,
#  np.float64(74229.0): 508,
#  np.float64(74230.0): 509,
#  np.float64(74231.0): 510,
#  np.float64(74232.0): 511,
#  np.float64(74233.0): 512,
#  np.float64(74235.0): 513,
#  np.float64(74238.0): 514,
#  np.float64(74239.0): 515,
#  np.float64(74240.0): 516,
#  np.float64(74241.0): 517,
#  np.float64(74242.0): 518,
#  np.float64(74243.0): 519,
#  np.float64(74245.0): 520,
#  np.float64(74247.0): 521,
#  np.float64(74248.0): 522,
#  np.float64(74249.0): 523,
#  np.float64(74251.0): 524,
#  np.float64(74252.0): 525,
#  np.float64(74253.0): 526,
#  np.float64(74254.0): 527,
#  np.float64(74255.0): 528,
#  np.float64(74256.0): 529,
#  np.float64(74259.0): 530,
#  np.float64(74262.0): 531,
#  np.float64(74263.0): 532,
#  np.float64(74264.0): 533,
#  np.float64(74265.0): 534,
#  np.float64(74267.0): 535,
#  np.float64(74268.0): 536,
#  np.float64(74269.0): 537,
#  np.float64(74270.0): 538,
#  np.float64(74271.0): 539,
#  np.float64(74273.0): 540,
#  np.float64(74274.0): 541,
#  np.float64(74275.0): 542,
#  np.float64(74276.0): 543,
#  np.float64(74277.0): 544,
#  np.float64(74278.0): 545,
#  np.float64(74279.0): 546,
#  np.float64(74280.0): 547,
#  np.float64(74281.0): 548,
#  np.float64(74283.0): 549,
#  np.float64(74284.0): 550,
#  np.float64(74285.0): 551,
#  np.float64(74286.0): 552,
#  np.float64(74287.0): 553,
#  np.float64(74288.0): 554,
#  np.float64(74290.0): 555,
#  np.float64(74291.0): 556,
#  np.float64(74292.0): 557,
#  np.float64(74293.0): 558,
#  np.float64(74294.0): 559,
#  np.float64(74295.0): 560,
#  np.float64(74296.0): 561,
#  np.float64(74297.0): 562,
#  np.float64(74298.0): 563,
#  np.float64(74300.0): 564,
#  np.float64(74301.0): 565,
#  np.float64(74302.0): 566,
#  np.float64(74303.0): 567,
#  np.float64(74304.0): 568,
#  np.float64(74305.0): 569,
#  np.float64(74306.0): 570,
#  np.float64(74307.0): 571,
#  np.float64(74308.0): 572,
#  np.float64(74310.0): 573,
#  np.float64(74311.0): 574,
#  np.float64(74312.0): 575,
#  np.float64(74313.0): 576,
#  np.float64(74314.0): 577,
#  np.float64(74315.0): 578,
#  np.float64(74317.0): 579,
#  np.float64(74318.0): 580,
#  np.float64(74319.0): 581,
#  np.float64(74322.0): 582,
#  np.float64(74323.0): 583,
#  np.float64(74324.0): 584,
#  np.float64(74325.0): 585,
#  np.float64(74326.0): 586,
#  np.float64(74327.0): 587,
#  np.float64(74328.0): 588,
#  np.float64(74330.0): 589,
#  np.float64(74331.0): 590,
#  np.float64(74332.0): 591,
#  np.float64(74334.0): 592,
#  np.float64(74335.0): 593,
#  np.float64(74336.0): 594,
#  np.float64(74339.0): 595,
#  np.float64(74340.0): 596,
#  np.float64(74341.0): 597,
#  np.float64(74342.0): 598,
#  np.float64(74345.0): 599,
#  np.float64(74346.0): 600,
#  np.float64(74347.0): 601,
#  np.float64(74348.0): 602,
#  np.float64(74349.0): 603,
#  np.float64(74351.0): 604,
#  np.float64(74356.0): 605,
#  np.float64(74358.0): 606,
#  np.float64(74359.0): 607,
#  np.float64(74360.0): 608,
#  np.float64(74361.0): 609,
#  np.float64(74364.0): 610,
#  np.float64(74365.0): 611,
#  np.float64(74366.0): 612,
#  np.float64(74367.0): 613,
#  np.float64(74369.0): 614,
#  np.float64(74370.0): 615,
#  np.float64(74372.0): 616,
#  np.float64(74373.0): 617,
#  np.float64(74374.0): 618,
#  np.float64(74375.0): 619,
#  np.float64(74377.0): 620,
#  np.float64(74378.0): 621,
#  np.float64(74379.0): 622,
#  np.float64(74380.0): 623,
#  np.float64(74381.0): 624,
#  np.float64(74382.0): 625,
#  np.float64(74383.0): 626,
#  np.float64(74384.0): 627,
#  np.float64(74385.0): 628,
#  np.float64(74386.0): 629,
#  np.float64(74388.0): 630,
#  np.float64(74390.0): 631,
#  np.float64(74392.0): 632,
#  np.float64(74393.0): 633,
#  np.float64(74394.0): 634,
#  np.float64(74395.0): 635,
#  np.float64(74396.0): 636,
#  np.float64(74397.0): 637,
#  np.float64(74398.0): 638,
#  np.float64(74399.0): 639,
#  np.float64(74400.0): 640,
#  np.float64(74401.0): 641,
#  np.float64(74402.0): 642,
#  np.float64(74403.0): 643,
#  np.float64(74405.0): 644,
#  np.float64(74407.0): 645,
#  np.float64(74408.0): 646,
#  np.float64(74410.0): 647,
#  np.float64(74412.0): 648,
#  np.float64(74416.0): 649,
#  np.float64(74417.0): 650,
#  np.float64(74418.0): 651,
#  np.float64(74419.0): 652,
#  np.float64(74420.0): 653,
#  np.float64(74421.0): 654,
#  np.float64(74424.0): 655,
#  np.float64(74425.0): 656,
#  np.float64(74427.0): 657,
#  np.float64(74430.0): 658,
#  np.float64(74431.0): 659,
#  np.float64(74432.0): 660,
#  np.float64(74433.0): 661,
#  np.float64(74434.0): 662,
#  np.float64(74435.0): 663,
#  np.float64(74436.0): 664,
#  np.float64(74437.0): 665,
#  np.float64(74440.0): 666,
#  np.float64(74442.0): 667,
#  np.float64(74443.0): 668,
#  np.float64(74444.0): 669,
#  np.float64(74445.0): 670,
#  np.float64(74446.0): 671,
#  np.float64(74448.0): 672,
#  np.float64(74449.0): 673,
#  np.float64(74450.0): 674,
#  np.float64(74451.0): 675,
#  np.float64(74452.0): 676,
#  np.float64(74455.0): 677,
#  np.float64(74457.0): 678,
#  np.float64(74458.0): 679,
#  np.float64(74459.0): 680,
#  np.float64(74460.0): 681,
#  np.float64(74463.0): 682,
#  np.float64(74464.0): 683,
#  np.float64(74465.0): 684,
#  np.float64(74466.0): 685,
#  np.float64(74468.0): 686,
#  np.float64(74471.0): 687,
#  np.float64(74474.0): 688,
#  np.float64(74476.0): 689,
#  np.float64(74478.0): 690,
#  np.float64(74479.0): 691,
#  np.float64(74480.0): 692,
#  np.float64(74481.0): 693,
#  np.float64(74482.0): 694,
#  np.float64(74483.0): 695,
#  np.float64(74484.0): 696,
#  np.float64(74485.0): 697,
#  np.float64(74486.0): 698,
#  np.float64(74487.0): 699,
#  np.float64(74489.0): 700,
#  np.float64(74491.0): 701,
#  np.float64(74492.0): 702,
#  np.float64(74493.0): 703,
#  np.float64(74495.0): 704,
#  np.float64(74496.0): 705,
#  np.float64(74498.0): 706,
#  np.float64(74499.0): 707,
#  np.float64(74500.0): 708,
#  np.float64(74501.0): 709,
#  np.float64(74504.0): 710,
#  np.float64(74505.0): 711,
#  np.float64(74506.0): 712,
#  np.float64(74507.0): 713,
#  np.float64(74508.0): 714,
#  np.float64(74509.0): 715,
#  np.float64(74510.0): 716,
#  np.float64(74511.0): 717,
#  np.float64(74512.0): 718,
#  np.float64(74513.0): 719,
#  np.float64(74516.0): 720,
#  np.float64(74523.0): 721,
#  np.float64(74524.0): 722,
#  np.float64(74525.0): 723,
#  np.float64(74529.0): 724,
#  np.float64(74532.0): 725,
#  np.float64(74534.0): 726,
#  np.float64(74536.0): 727,
#  np.float64(74537.0): 728,
#  np.float64(74538.0): 729,
#  np.float64(74539.0): 730,
#  np.float64(74540.0): 731,
#  np.float64(74541.0): 732,
#  np.float64(74542.0): 733,
#  np.float64(74544.0): 734,
#  np.float64(74545.0): 735,
#  np.float64(74546.0): 736,
#  np.float64(74547.0): 737,
#  np.float64(74548.0): 738,
#  np.float64(74549.0): 739,
#  np.float64(74550.0): 740,
#  np.float64(74552.0): 741,
#  np.float64(74553.0): 742,
#  np.float64(74554.0): 743,
#  np.float64(74556.0): 744,
#  np.float64(74557.0): 745,
#  np.float64(74559.0): 746,
#  np.float64(74560.0): 747,
#  np.float64(74562.0): 748,
#  np.float64(74563.0): 749,
#  np.float64(74565.0): 750,
#  np.float64(74566.0): 751,
#  np.float64(74567.0): 752,
#  np.float64(74568.0): 753,
#  np.float64(74569.0): 754,
#  np.float64(74570.0): 755,
#  np.float64(74571.0): 756,
#  np.float64(74573.0): 757,
#  np.float64(74574.0): 758,
#  np.float64(74575.0): 759,
#  np.float64(74576.0): 760,
#  np.float64(74578.0): 761,
#  np.float64(74579.0): 762,
#  np.float64(74580.0): 763,
#  np.float64(74582.0): 764,
#  np.float64(74583.0): 765,
#  np.float64(74584.0): 766,
#  np.float64(74587.0): 767,
#  np.float64(74588.0): 768,
#  np.float64(74589.0): 769,
#  np.float64(74591.0): 770,
#  np.float64(74594.0): 771,
#  np.float64(74595.0): 772,
#  np.float64(74596.0): 773,
#  np.float64(74598.0): 774,
#  np.float64(74600.0): 775,
#  np.float64(74601.0): 776,
#  np.float64(74602.0): 777,
#  np.float64(74603.0): 778,
#  np.float64(74606.0): 779,
#  np.float64(74607.0): 780,
#  np.float64(74608.0): 781,
#  np.float64(74609.0): 782,
#  np.float64(74611.0): 783,
#  np.float64(74612.0): 784,
#  np.float64(74613.0): 785,
#  np.float64(74614.0): 786,
#  np.float64(74615.0): 787,
#  np.float64(74617.0): 788,
#  np.float64(74619.0): 789,
#  np.float64(74620.0): 790,
#  np.float64(74623.0): 791,
#  np.float64(74624.0): 792,
#  np.float64(74626.0): 793,
#  np.float64(74627.0): 794,
#  np.float64(74628.0): 795,
#  np.float64(74629.0): 796,
#  np.float64(74630.0): 797,
#  np.float64(74631.0): 798,
#  np.float64(74632.0): 799,
#  np.float64(74633.0): 800,
#  np.float64(74636.0): 801,
#  np.float64(74638.0): 802,
#  np.float64(74639.0): 803,
#  np.float64(74642.0): 804,
#  np.float64(74644.0): 805,
#  np.float64(74645.0): 806,
#  np.float64(74646.0): 807,
#  np.float64(74647.0): 808,
#  np.float64(74648.0): 809,
#  np.float64(74649.0): 810,
#  np.float64(74650.0): 811,
#  np.float64(74651.0): 812,
#  np.float64(74652.0): 813,
#  np.float64(74653.0): 814,
#  np.float64(74654.0): 815,
#  np.float64(74655.0): 816,
#  np.float64(74656.0): 817,
#  np.float64(74657.0): 818,
#  np.float64(74658.0): 819,
#  np.float64(74659.0): 820,
#  np.float64(74660.0): 821,
#  np.float64(74661.0): 822,
#  np.float64(74662.0): 823,
#  np.float64(74663.0): 824,
#  np.float64(74666.0): 825,
#  np.float64(74668.0): 826,
#  np.float64(74669.0): 827,
#  np.float64(74671.0): 828,
#  np.float64(74672.0): 829,
#  np.float64(74673.0): 830,
#  np.float64(74674.0): 831,
#  np.float64(74675.0): 832,
#  np.float64(74676.0): 833,
#  np.float64(74677.0): 834,
#  np.float64(74678.0): 835,
#  np.float64(74679.0): 836,
#  np.float64(74680.0): 837,
#  np.float64(74681.0): 838,
#  np.float64(74682.0): 839,
#  np.float64(74683.0): 840,
#  np.float64(74685.0): 841,
#  np.float64(74686.0): 842,
#  np.float64(74688.0): 843,
#  np.float64(74689.0): 844,
#  np.float64(74690.0): 845,
#  np.float64(74691.0): 846,
#  np.float64(74693.0): 847,
#  np.float64(74694.0): 848,
#  np.float64(74695.0): 849,
#  np.float64(74696.0): 850,
#  np.float64(74697.0): 851,
#  np.float64(74698.0): 852,
#  np.float64(74699.0): 853,
#  np.float64(74700.0): 854,
#  np.float64(74701.0): 855,
#  np.float64(74702.0): 856,
#  np.float64(74703.0): 857,
#  np.float64(74704.0): 858,
#  np.float64(74705.0): 859,
#  np.float64(74706.0): 860,
#  np.float64(74707.0): 861,
#  np.float64(74710.0): 862,
#  np.float64(74711.0): 863,
#  np.float64(74714.0): 864,
#  np.float64(74715.0): 865,
#  np.float64(74718.0): 866,
#  np.float64(74719.0): 867,
#  np.float64(74720.0): 868,
#  np.float64(74721.0): 869,
#  np.float64(74722.0): 870,
#  np.float64(74723.0): 871,
#  np.float64(74724.0): 872,
#  np.float64(74725.0): 873,
#  np.float64(74727.0): 874,
#  np.float64(74728.0): 875,
#  np.float64(74730.0): 876,
#  np.float64(74732.0): 877,
#  np.float64(74733.0): 878,
#  np.float64(74734.0): 879,
#  np.float64(74735.0): 880,
#  np.float64(74736.0): 881,
#  np.float64(74738.0): 882,
#  np.float64(74739.0): 883,
#  np.float64(74740.0): 884,
#  np.float64(74741.0): 885,
#  np.float64(74742.0): 886,
#  np.float64(74743.0): 887,
#  np.float64(74744.0): 888,
#  np.float64(74745.0): 889,
#  np.float64(74746.0): 890,
#  np.float64(74747.0): 891,
#  np.float64(74748.0): 892,
#  np.float64(74749.0): 893,
#  np.float64(74751.0): 894,
#  np.float64(74752.0): 895,
#  np.float64(74753.0): 896,
#  np.float64(74754.0): 897,
#  np.float64(74755.0): 898,
#  np.float64(74756.0): 899,
#  np.float64(74759.0): 900,
#  np.float64(74760.0): 901,
#  np.float64(74761.0): 902,
#  np.float64(74762.0): 903,
#  np.float64(74763.0): 904,
#  np.float64(74765.0): 905,
#  np.float64(74767.0): 906,
#  np.float64(74770.0): 907,
#  np.float64(74771.0): 908,
#  np.float64(74772.0): 909,
#  np.float64(74774.0): 910,
#  np.float64(74776.0): 911,
#  np.float64(74778.0): 912,
#  np.float64(74779.0): 913,
#  np.float64(74781.0): 914,
#  np.float64(74782.0): 915,
#  np.float64(74783.0): 916,
#  np.float64(74785.0): 917,
#  np.float64(74786.0): 918,
#  np.float64(74787.0): 919,
#  np.float64(74788.0): 920,
#  np.float64(74789.0): 921,
#  np.float64(74791.0): 922,
#  np.float64(74793.0): 923,
#  np.float64(74795.0): 924,
#  np.float64(74796.0): 925,
#  np.float64(74797.0): 926,
#  np.float64(74798.0): 927,
#  np.float64(74800.0): 928,
#  np.float64(74801.0): 929,
#  np.float64(74802.0): 930,
#  np.float64(74804.0): 931,
#  np.float64(74805.0): 932,
#  np.float64(74809.0): 933,
#  np.float64(74813.0): 934,
#  np.float64(74814.0): 935,
#  np.float64(74815.0): 936,
#  np.float64(74816.0): 937,
#  np.float64(74817.0): 938,
#  np.float64(74818.0): 939,
#  np.float64(74821.0): 940,
#  np.float64(74822.0): 941,
#  np.float64(74823.0): 942,
#  np.float64(74824.0): 943,
#  np.float64(74825.0): 944,
#  np.float64(74828.0): 945,
#  np.float64(74829.0): 946,
#  np.float64(74830.0): 947,
#  np.float64(74831.0): 948,
#  np.float64(74832.0): 949,
#  np.float64(74833.0): 950,
#  np.float64(74835.0): 951,
#  np.float64(74836.0): 952,
#  np.float64(74837.0): 953,
#  np.float64(74839.0): 954,
#  np.float64(74840.0): 955,
#  np.float64(74844.0): 956,
#  np.float64(74845.0): 957,
#  np.float64(74848.0): 958,
#  np.float64(74852.0): 959,
#  np.float64(74855.0): 960,
#  np.float64(74856.0): 961,
#  np.float64(74857.0): 962,
#  np.float64(74859.0): 963,
#  np.float64(74860.0): 964,
#  np.float64(74861.0): 965,
#  np.float64(74862.0): 966,
#  np.float64(74864.0): 967,
#  np.float64(74866.0): 968,
#  np.float64(74867.0): 969,
#  np.float64(74868.0): 970,
#  np.float64(74869.0): 971,
#  np.float64(74874.0): 972,
#  np.float64(74875.0): 973,
#  np.float64(74877.0): 974,
#  np.float64(74878.0): 975,
#  np.float64(74880.0): 976,
#  np.float64(74881.0): 977,
#  np.float64(74882.0): 978,
#  np.float64(74883.0): 979,
#  np.float64(74885.0): 980,
#  np.float64(74886.0): 981,
#  np.float64(74887.0): 982,
#  np.float64(74889.0): 983,
#  np.float64(74890.0): 984,
#  np.float64(74893.0): 985,
#  np.float64(74894.0): 986,
#  np.float64(74895.0): 987,
#  np.float64(74896.0): 988,
#  np.float64(74897.0): 989,
#  np.float64(74900.0): 990,
#  np.float64(74901.0): 991,
#  np.float64(74903.0): 992,
#  np.float64(74904.0): 993,
#  np.float64(74905.0): 994,
#  np.float64(74907.0): 995,
#  np.float64(74909.0): 996,
#  np.float64(74910.0): 997,
#  np.float64(74911.0): 998,
#  np.float64(74912.0): 999,
#  ...}

# %% [markdown]
# train_ids y test_ids contain the SEQN of the subjects in the training and testing set, respectively.

# %%
train_ids['SEQN'].iloc[0]
# Out:
# np.float64(73729.0)

# %% [markdown]
# seqn_to_index is a dictionary that maps the SEQN to the index of the subject in the data matrix.

# %%
seqn_to_index[train_ids['SEQN'].iloc[0]]
# Out:
# 136

# %%
seqn_to_index[73729]
# Out:
# 136

# %% [markdown]
# subjects_seqn is a list with the SEQN of the subjects in the data matrix in the order they appear in the data matrix.

# %%
subjects_seqn['SEQN'].iloc[136]
# Out:
# np.float64(73729.0)

# %% [markdown]
# Would it be better to have physical_activity and subjects_seqn in a single data structure such as a dictionary or a class?

# %% [markdown]
# ## 2 Functions

# %%
def create_gaf_image(one_day_acc):
    """
    Creates a 2D GAF image from the accelerometry data of a single day, for a single subject (input in a 2d numpy array).
    """
    gaf_model = GramianAngularField(method='difference')
    gaf = gaf_model.fit_transform(one_day_acc)
    if gaf.ndim == 3:  # If the output is 3D, reduce it to 2D
        return gaf.squeeze(0)  # Assume the shape is (1, height, width) and we need (height, width)
    return gaf

# %%
def plot_gaf_image(gaf_image):
    """
    This function plots a GAF image
    """
    fig_w=4; fig_h=4;# figure width and height
    plt.figure(figsize=(fig_w, fig_h))
    #plt.imshow(gaf_image[0], cmap='rainbow', origin='lower')
    plt.imshow(gaf_image, cmap='rainbow', origin='lower')
    plt.axis('off')
    plt.show()

# %%
def average_over_periods(data, period_length):
    """
    Averages data over specified period lengths.

    Parameters:
    data (numpy array): The input data array to be averaged.
    period_length (int): The length of each period over which to average the data.

    Returns:
    numpy array: The array containing the averaged data.
    """
    # Ensure the data can be evenly divided into periods of the specified length
    if len(data) % period_length != 0:
        raise ValueError("The length of the data is not evenly divisible by the period length.")

    # Reshape the data into chunks and calculate the mean for each chunk
    reshaped_data = data.reshape(-1, period_length)
    averaged_data = reshaped_data.mean(axis=1)

    return averaged_data

# %%
def resample_acceleration_data(matrix_3d, period_length):
    # Get the shape of the original matrix
    nof_subjects, nof_days, nof_minutes = matrix_3d.shape

    # Ensure the data can be evenly divided into periods of the specified length
    if nof_minutes % period_length != 0:
        raise ValueError("The length of the data (1440) is not evenly divisible by the period length. Period_length must be a factor of 1440.")

    # Calculate the new number of minutes after resampling
    new_nof_minutes = nof_minutes // period_length

    # Initialize a new 3D matrix to store the resampled data
    matrix_3d_resampled = np.zeros((nof_subjects, nof_days, new_nof_minutes))

    # Iterate over each subject and each day
    for subject_idx in range(nof_subjects):
        for day_idx in range(nof_days):
            # Get the acceleration vector for the current subject and day
            acceleration_vector = matrix_3d[subject_idx, day_idx]

            # Apply the average_over_periods function to the acceleration vector
            resampled_vector = average_over_periods(acceleration_vector, period_length)

            # Store the resampled vector in the new 3D matrix
            matrix_3d_resampled[subject_idx, day_idx] = resampled_vector

    return matrix_3d_resampled

# %% [markdown]
# ## 3 Creating the tensors from the time series data

# %% [markdown]
# For each subject, a tensor (npy file) is created. This tensor contains 7 GAF images, one for each day of the week. The size of the image can be downsampled from 1440, by selecting how many minutes per acceleration sample we want to keep.
# So for each subject, we have a tensor of size
# - [n_samples_per_day, n_samples_per_day, days_per_week:7]

# %%
# Define the directory path where the files will be saved.
directory_path = 'tensors_144'
# directory_path = 'tensors_288'
# directory_path = 'tensors_720'

# %%
def create_subject_tensor_resampled(subject_ids, physical_activity, prefix, minutes_per_sample):
    """
    Process each subject and store GAF images as separate 3D tensors in the format:
    (n_samples_per_day, n_samples_per_day, days_per_week).
    Each tensor for a subject's week is saved in an individual file named {prefix}_{seqn}_{n_samples_per_day}.npy.
    """

    # Resample the acceleration data to the specified number of minutes per sample
    physical_activity_resampled = resample_acceleration_data(physical_activity, minutes_per_sample)
    n_samples_per_day = physical_activity_resampled.shape[2]

    for seqn in subject_ids['SEQN']:
        subject_idx = seqn_to_index[seqn]
        weekly_gafs = []
        for day_idx in range(physical_activity_resampled.shape[1]):  # Assuming there are 7 days
            physical_activity_day = physical_activity_resampled[subject_idx, day_idx]
            gaf = create_gaf_image(physical_activity_day.reshape(1, n_samples_per_day))
            weekly_gafs.append(gaf)

        # Stack all GAF images along the third axis to form a 3D tensor for the week
        full_week_gaf = np.stack(weekly_gafs, axis=2)

        # Save the 3D tensor to a file, named using the subject's SEQN and the specified prefix
        filename = os.path.join(directory_path, f'{prefix}_{int(seqn)}_{n_samples_per_day}.npy')
        np.save(filename, full_week_gaf)

# %%
minutes_per_sample=10
#minutes_per_sample=5
#minutes_per_sample=2 #con 2 falla la memoria
create_subject_tensor_resampled(test_ids, physical_activity, "test", minutes_per_sample) # Limiting for debugging
create_subject_tensor_resampled(train_ids, physical_activity, "train", minutes_per_sample) # Limiting for debugging

# %% [markdown]
# # Más adelante prueba si hay mejoras reduciendo el número de minutos por muestra.

# %%
len(os.listdir('/content/drive/MyDrive/Colab Notebooks/deep_acelerometry/tensors_144'))
# Out:
# 2504

# %% [markdown]
# ### Si selecciono minutes_per_sample=2 se supera la capacidad de memoria que permite la GPU de colab y da error. Quédate de momento con 5 y 10 minutos.

# %%
test_77845_144 = np.load(os.path.join(directory_path, 'test_77845_144.npy'))

# %%
test_77845_144.shape
# Out:
# (144, 144, 7)
